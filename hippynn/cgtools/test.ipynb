# %%
from hippynn.cgtools.readers import extract_trajectory_data
from hippynn.cgtools.coarse_grain import coarse

# %%
src = "/home/eshinkle/Projects/coarse-graining/investigative_codes/mixtures/ethaline_100/data/temp_298dot15_counts_250-250-500_0"

results = extract_trajectory_data(trajectory=src + "/ec.trr", topology=src + "/system.pdb")

print(results.keys())
# Out:
# dict_keys(['positions', 'velocities', 'forces', 'cells', 'masses', 'species', 'mol_ids'])
